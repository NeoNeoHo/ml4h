# %% [markdown]
# # Regression Plot

# %% [markdown]
# Learn From StatsModels
# http://statsmodels.sourceforge.net/devel/examples/notebooks/generated/example_regression_plots.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
prestige = sm.datasets.get_rdataset('Duncan', 'car', cache=True).data
prestige.head()
# Out:
#             type  income  education  prestige
# accountant  prof      62         86        82
# pilot       prof      72         76        83
# architect   prof      75         92        90
# author      prof      55         90        76
# chemist     prof      64         86        90

# %%
prestige_model = ols('prestige ~ income + education', data =prestige).fit()
print prestige_model.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               prestige   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     101.2
# Date:                Tue, 20 Jan 2015   Prob (F-statistic):           8.65e-17
# Time:                        22:48:32   Log-Likelihood:                -178.98
# No. Observations:                  45   AIC:                             364.0
# Df Residuals:                      42   BIC:                             369.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -6.0647      4.272     -1.420      0.163       -14.686     2.556
# income         0.5987      0.120      5.003      0.000         0.357     0.840
# education      0.5458      0.098      5.555      0.000         0.348     0.744
# ==============================================================================
# Omnibus:                        1.279   Durbin-Watson:                   1.458
# Prob(Omnibus):                  0.528   Jarque-Bera (JB):                0.520
# Skew:                           0.155   Prob(JB):                        0.771
# Kurtosis:                       3.426   Cond. No.                         163.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig, ax = plt.subplots(figsize=(10,8))
fig = sm.graphics.influence_plot(prestige_model, ax = ax, criterion='cooks')

# %%
fig, ax = plt.subplots(figsize = (12, 5))
fig = sm.graphics.plot_partregress('prestige', 'income', ['education'], data=prestige, ax=ax, obs_labels=True)
ax = fig.axes[0]
